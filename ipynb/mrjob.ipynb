# %%
# This runs the wordcount.py script.
# When you run it, it'll output a bunch of stderr telling you how it's going
# Then, it'll output some of the output

# %run /home/python/mrjob_scripts/wordcount.py /home/python/data/wcdata/shakes*
# Out:
# no configs found; falling back on auto-configuration
# INFO:mrjob.conf:no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# INFO:mrjob.conf:no configs found; falling back on auto-configuration
# creating tmp directory /tmp/wordcount.python.20150408.145613.093301
# INFO:mrjob.runner:creating tmp directory /tmp/wordcount.python.20150408.145613.093301
# writing to /tmp/wordcount.python.20150408.145613.093301/step-0-mapper_part-00000
# INFO:mrjob.sim:writing to /tmp/wordcount.python.20150408.145613.093301/step-0-mapper_part-00000
# writing to /tmp/wordcount.python.20150408.145613.093301/step-0-mapper_part-00001
# INFO:mrjob.sim:writing to /tmp/wordcount.python.20150408.145613.093301/step-0-mapper_part-00001
# writing to /tmp/wordcount.python.20150408.145613.093301/step-0-mapper_part-00002
# INFO:mrjob.sim:writing to /tmp/wordcount.python.20150408.145613.093301/step-0-mapper_part-00002
# Counters from step 1:
# ...

# %%
# This runs the avg.py script
# This will print out a bunch of counters that are kept track of during operation
# The output is at the very end

# %run /home/python/mrjob_scripts/avg.py /home/python/data/salarydata/*
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# INFO:mrjob.conf:no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# INFO:mrjob.conf:no configs found; falling back on auto-configuration
# creating tmp directory /tmp/avg.python.20150407.183036.757046
# creating tmp directory /tmp/avg.python.20150407.183036.757046
# creating tmp directory /tmp/avg.python.20150407.183036.757046
# creating tmp directory /tmp/avg.python.20150407.183036.757046
# INFO:mrjob.runner:creating tmp directory /tmp/avg.python.20150407.183036.757046
# writing to /tmp/avg.python.20150407.183036.757046/step-0-mapper_part-00000
# ...

# %%
# %run /home/python/mrjob_scripts/max.py /home/python/data/salarydata/*
# Out:
# no configs found; falling back on auto-configuration
# INFO:mrjob.conf:no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# INFO:mrjob.conf:no configs found; falling back on auto-configuration
# creating tmp directory /tmp/max.python.20150407.205602.311982
# INFO:mrjob.runner:creating tmp directory /tmp/max.python.20150407.205602.311982
# writing to /tmp/max.python.20150407.205602.311982/step-0-mapper_part-00000
# INFO:mrjob.sim:writing to /tmp/max.python.20150407.205602.311982/step-0-mapper_part-00000
# Counters from step 1:
# INFO:mrjob.runner:Counters from step 1:
#   warn:
# INFO:mrjob.runner:  warn:
#     missing gross: 3223
# INFO:mrjob.runner:    missing gross: 3223
# writing to /tmp/max.python.20150407.205602.311982/step-0-mapper-sorted
# INFO:mrjob.runner:writing to /tmp/max.python.20150407.205602.311982/step-0-mapper-sorted
# > sort /tmp/max.python.20150407.205602.311982/step-0-mapper_part-00000
# ...

# %%
# This is the solution of the seniority exercise.
# Take a look at what the output should look like!
# !python /home/python/mrjob_scripts/seniority_solution/seniority_v_pay.py ~/data/salarydata/BaltimoreSalaries.csv | sort -n
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# creating tmp directory /tmp/seniority_v_pay.python.20150408.145921.519481
# writing to /tmp/seniority_v_pay.python.20150408.145921.519481/step-0-mapper_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /tmp/seniority_v_pay.python.20150408.145921.519481/step-0-mapper-sorted
# > sort /tmp/seniority_v_pay.python.20150408.145921.519481/step-0-mapper_part-00000
# writing to /tmp/seniority_v_pay.python.20150408.145921.519481/step-0-reducer_part-00000
# Counters from step 1:
#   (no counters found)
# Moving /tmp/seniority_v_pay.python.20150408.145921.519481/step-0-reducer_part-00000 -> /tmp/seniority_v_pay.python.20150408.145921.519481/output/part-00000
# Streaming final output from /tmp/seniority_v_pay.python.20150408.145921.519481/output
# removing tmp directory /tmp/seniority_v_pay.python.20150408.145921.519481
# -1	[65351, 70]
# 0	[11310, 2793]
# ...

# %%
# !python /home/python/mrjob_scripts/seniority_v_pay.py ~/data/salarydata/BaltimoreSalaries.csv | sort -n
